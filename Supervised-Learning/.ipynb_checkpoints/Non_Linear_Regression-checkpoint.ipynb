# %% [markdown]
# <h1><center>Non Linear Regression Analysis</center></h1>
#
# If the data shows a curvy trend, then linear regression will not produce very accurate results when compared to a non-linear regression because, as the name implies, linear regression presumes that the data is linear.
# Let's learn about non linear regressions and apply an example on python. In this notebook, we fit a non-linear model to the datapoints corrensponding to China's GDP from 1960 to 2014.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Linear Regression

# %%
# we will try to model using linear regression using a linear function y = 2x+3

x = np.arange(-5.0, 5.0, 0.1)

#You can adjust the slope and intercept to verify the changes in the graph
y = 2*(x) + 3
y_noise = 2 * np.random.normal(size=x.size)
ydata = y + y_noise
#plt.figure(figsize=(8,6))
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# # Cubic Function Non Linear Regression

# %%
# now we will try to model using non linear regression using a cubic function  y = x³+x²+x+3

x = np.arange(-5.0, 5.0, 0.1)

#You can adjust the slope and intercept to verify the changes in the graph
y = 1*(x**3) + 1*(x**2) + 1*x + 3
y_noise = 20 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# # Quadratic Function Non Linear Regression

# %%
# now we will try to model using non linear regression using a quadratic function  y = x²

x = np.arange(-5.0, 5.0, 0.1)

#You can adjust the slope and intercept to verify the changes in the graph

y = np.power(x,2)
y_noise = 2 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# # Exponential Function Non Linear Regression

# %%
# now we will try to model using non linear regression using an exponential function  y = a + b(c^x)

X = np.arange(-5.0, 5.0, 0.1)

#You can adjust the slope and intercept to verify the changes in the graph

Y= np.exp(X)

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# # Logarathmic Function Non Linear Regression

# %%
# now we will try to model using non linear regression using an logarithmic function  y = log(x)

X = np.arange(-5.0, 5.0, 0.1)

#You can adjust the slope and intercept to verify the changes in the graph
Y = np.log(X)

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()
# Out:
# C:\Users\vedan\anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in log

# %% [markdown]
# # Logistic / Sigmoid Function Non Linear Regression

# %%
# now we will try to model using non linear regression using an logistic aka sigmoid function  y = a+(b/1+(c^(x-d)))

X = np.arange(-5.0, 5.0, 0.1)


Y = 1-4/(1+np.power(3, X-2))

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# # Non Linear Regression

# %%
#taking a look at the data

df = pd.read_csv('china_gdp.csv')
df.head(10)
# Out:
#    Year         Value
# 0  1960  5.918412e+10
# 1  1961  4.955705e+10
# 2  1962  4.668518e+10
# 3  1963  5.009730e+10
# 4  1964  5.906225e+10
# 5  1965  6.970915e+10
# 6  1966  7.587943e+10
# 7  1967  7.205703e+10
# 8  1968  6.999350e+10
# 9  1969  7.871882e+10

# %%
# plotting the dataset
plt.figure(figsize=(8,5))
x_data, y_data = (df['Year'].values, df['Value'].values)
plt.plot(x_data, y_data, 'ro')
plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()

# %%
# chosing a model as we can see the data is non linear
# we will chose a logistic function y = 1/(1+(e^b1(x-b2))
# where b1 is the steepness of the curve and b2 slides the curve on the x axis

x = np.arange(-5.0, 5.0, 0.1)
y = 1.0/(1.0+np.exp(-x))

plt.plot(x,y)
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %%
# building the model

def sigmoid(x, Beta_1, Beta_2):
    y = 1/(1+np.exp(-Beta_1*(x-Beta_2)))
    return y

# %%
# fitting the data in the model
beta_1 = 0.1
beta_2 = 1990.0

y_pred = sigmoid(x_data, beta_1, beta_2)

# plotting the initial predictions against the data points
plt.plot(x_data, y_pred*15000000000000.)
plt.plot(x_data, y_data, 'ro')

# %%
# to find the best parameters we will first normalise our x and y
xdata = x_data/max(x_data)
ydata = y_data/max(y_data)

# %%
# finding the best parapemters using curve_fit
from scipy.optimize import curve_fit

popt, pcov = curve_fit(sigmoid, xdata, ydata)

# printing the parameters
print(' beta_1 = %f\n beta_2 = %f' % (popt[0], popt[1]))
# Out:
#  beta_1 = 690.451711
#  beta_2 = 0.997207

# %%
# plotting the resulting regression model

x = np.linspace(1960, 2015, 55)
x = x/max(x)
plt.figure(figsize=(8,5))
y = sigmoid(x, *popt)
plt.plot(xdata,ydata,'ro',label='data')
plt.plot(x,y, linewidth=3.0, label='fit')
plt.legend(loc='best')
plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()

# %%
# write your code here

# split data into train/test
msk = np.random.rand(len(df)) < 0.8
X_train = xdata[msk]
X_test = xdata[~msk]
y_train = ydata[msk]
y_test = ydata[~msk]

# build the model using train set
popt, pcov = curve_fit(sigmoid, X_train, y_train)

# predict using test set
y_pred = sigmoid(X_test, *popt)

# evaluation
print("Mean absolute error: %.2f" % np.mean(np.absolute(y_pred - y_test)))
print("Residual sum of squares (MSE): %.2f" % np.mean((y_pred - y_test) ** 2))
from sklearn.metrics import r2_score
print("R2-score: %.2f" % r2_score(y_pred , y_test) )
# Out:
# Mean absolute error: 0.03
# Residual sum of squares (MSE): 0.00
# R2-score: 0.96
